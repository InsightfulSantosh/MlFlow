# %% [markdown]
# ## **Import dependency**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Read the data set:**

# %%
df=pd.read_csv("titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# columns to drop

columns_to_drop = ['passengerid','name','ticket','cabin']

# %%
def clean_data(df):
    return (
        df
        .rename(columns=str.lower)
        .drop(columns=columns_to_drop)
        .assign(
            family = lambda df_ : df_['sibsp'] + df_['parch']
        )
        .drop(columns=['sibsp','parch'])

    )



final=df.pipe(clean_data)

# %%
final
# Out:
#      survived  pclass     sex   age     fare embarked  family
# 0           0       3    male  22.0   7.2500        S       1
# 1           1       1  female  38.0  71.2833        C       1
# 2           1       3  female  26.0   7.9250        S       0
# 3           1       1  female  35.0  53.1000        S       1
# 4           0       3    male  35.0   8.0500        S       0
# ..        ...     ...     ...   ...      ...      ...     ...
# 886         0       2    male  27.0  13.0000        S       0
# 887         1       1  female  19.0  30.0000        S       0
# 888         0       3  female   NaN  23.4500        S       3
# 889         1       1    male  26.0  30.0000        C       0
# 890         0       3    male  32.0   7.7500        Q       0
#
# [891 rows x 7 columns]

# %%
final.duplicated().sum()
# Out:
# np.int64(112)

# %%
final=final.drop_duplicates(keep="first")

# %%
final.duplicated().sum()
# Out:
# np.int64(0)

# %%
final.isna().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         103
# fare          0
# embarked      2
# family        0
# dtype: int64

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 779 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  779 non-null    int64
#  1   pclass    779 non-null    int64
#  2   sex       779 non-null    object
#  3   age       676 non-null    float64
#  4   fare      779 non-null    float64
#  5   embarked  777 non-null    object
#  6   family    779 non-null    int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 48.7+ KB

# %% [markdown]
# ## **EDA**

# %%
# distribution of target

(
    final
    .loc[:,'survived']
    .value_counts(normalize=True)
)
# Out:
# survived
# 0    0.587933
# 1    0.412067
# Name: proportion, dtype: float64

# %%
final.select_dtypes(include=['object']).describe()
# Out:
#          sex embarked
# count    779      777
# unique     2        3
# top     male        S
# freq     488      565

# %%
final
# Out:
#      survived  pclass     sex   age     fare embarked  family
# 0           0       3    male  22.0   7.2500        S       1
# 1           1       1  female  38.0  71.2833        C       1
# 2           1       3  female  26.0   7.9250        S       0
# 3           1       1  female  35.0  53.1000        S       1
# 4           0       3    male  35.0   8.0500        S       0
# ..        ...     ...     ...   ...      ...      ...     ...
# 885         0       3  female  39.0  29.1250        Q       5
# 887         1       1  female  19.0  30.0000        S       0
# 888         0       3  female   NaN  23.4500        S       3
# 889         1       1    male  26.0  30.0000        C       0
# 890         0       3    male  32.0   7.7500        Q       0
#
# [779 rows x 7 columns]

# %% [markdown]
# ## **Boxplot for `age`,`fare` & `family`**

# %%
def plot_boxplots(df):
    numeric_cols =["age","fare","family"]
    n_cols=3 
    n_rows = (len(numeric_cols) + n_cols - 1) // n_cols  # Ensure enough rows to fit all plots
    plt.figure(figsize=(n_cols * 6, 8 * n_rows))
    sns.set(style="darkgrid")
    for i, col in enumerate(numeric_cols):
        plt.subplot(n_rows, n_cols, i+1)
        sns.boxplot(data=df, y=col)
        plt.title(f'Distribution of {col}', fontsize=15)
        plt.ylabel('')
    plt.tight_layout()
    plt.show()

final.pipe(plot_boxplots)

# %% [markdown]
# ## **Countplot for `gender` & `embarked`**

# %%
def count_plot(df):
    # Select columns with object data type (categorical columns)
    obj_cols = df.select_dtypes("object").columns
    
    # Calculate the number of rows and columns for subplots
    n_cols=3 
    n_rows = (len(obj_cols) + n_cols - 1) // n_cols  # Ensure enough rows to fit all plots    
    # Limit the figure size to avoid exceeding max size
    plt.figure(figsize=(n_cols * 4,3  * n_rows))
    
    # Loop through the categorical columns to create boxplots
    for i, col in enumerate(obj_cols):
        # Create a subplot for each boxplot
        plt.subplot(n_rows, n_cols, i + 1)
        
        # Create a countplot for each categorical column (since boxplots are for numerical data)
        sns.countplot(data=df, x=col)
        
        # Set title for each subplot
        plt.title(f'Distribution of {col}', fontsize=15)
    
    # Adjust layout to prevent overlap
    plt.tight_layout()
    
    # Show the plots
    plt.show()

final.pipe(count_plot)

# %% [markdown]
# ## **feature engineering:**

# %%
! pip install feature_engine --q

# %%
x= final.drop(columns="survived")
y=final.survived

# %%
from sklearn.model_selection import train_test_split
from sklearn import set_config
from sklearn.ensemble import RandomForestClassifier

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, FeatureUnion

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (
    StandardScaler,
    MinMaxScaler,
    OneHotEncoder,
    OrdinalEncoder
)
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
from feature_engine.encoding import CountFrequencyEncoder
from feature_engine.outliers.winsorizer import Winsorizer

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)
print('The shape of training data is',x_train.shape)
print('The shape of testing data is',x_test.shape)
# Out:
# The shape of training data is (623, 6)
# The shape of testing data is (156, 6)

# %% [markdown]
# ## **Pipelines for Individual Columns**

# %%
x.columns
# Out:
# Index(['pclass', 'sex', 'age', 'fare', 'embarked', 'family'], dtype='object')

# %%
# age_pipeline
age_pipe = Pipeline(steps=[
    ('impute',SimpleImputer(strategy='median')),
    ('outliers',Winsorizer(capping_method='gaussian',fold=3)),
    ('scale',StandardScaler())
])


age_pipe
# Out:
# Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
#                 ('outliers', Winsorizer(fold=3)), ('scale', StandardScaler())])

# %%
# embarked_pipeline
embarked_pipe= Pipeline(steps=[("impute",SimpleImputer(strategy="most_frequent")),
                             ('count_encode',CountFrequencyEncoder(encoding_method='count')),
                             ("scale",MinMaxScaler())
                             
])
embarked_pipe
# Out:
# Pipeline(steps=[('impute', SimpleImputer(strategy='most_frequent')),
#                 ('count_encode', CountFrequencyEncoder()),
#                 ('scale', MinMaxScaler())])

# %%
# fare_pipeline
fare_pipe=Pipeline(steps=[
    ('outliers',Winsorizer(capping_method='iqr',fold=1.5)),
    ("scale",StandardScaler())
])
fare_pipe
# Out:
# Pipeline(steps=[('outliers', Winsorizer(capping_method='iqr', fold=1.5)),
#                 ('scale', StandardScaler())])

# %% [markdown]
# ## **Column Transformer:**

# %%
set_config(transform_output='pandas')

# %%
x.head(2)
# Out:
#    pclass     sex   age     fare embarked  family
# 0       3    male  22.0   7.2500        S       1
# 1       1  female  38.0  71.2833        C       1

# %%
# Create the ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ("age", age_pipe, ["age"]),
        ("fare", fare_pipe, ["fare"]),
        ("embarked_", embarked_pipe, ["embarked"]),
        ("sex", OneHotEncoder(sparse_output=False, handle_unknown='ignore'), ["sex"]),
        ("family", MinMaxScaler(), ["family"])
    ],
    remainder="passthrough",  # Any columns not listed will pass through without modification
    n_jobs=-1,  # Number of jobs to run in parallel (set to -1 to use all cores)
)
preprocessor
# Out:
# ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                   transformers=[('age',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('outliers',
#                                                   Winsorizer(fold=3)),
#                                                  ('scale', StandardScaler())]),
#                                  ['age']),
#                                 ('fare',
#                                  Pipeline(steps=[('outliers',
#                                                   Winsorizer(capping_method='iqr',
#                                                              fold=1.5)),
#                                                  ('scale', StandardScaler())]),
#                                  ['fare']),
#                                 ('embarked_',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('count_encode',
#                                                   CountFrequencyEncoder()),
#                                                  ('scale', MinMaxScaler())]),
#                                  ['embarked']),
#                                 ('sex',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['sex']),
#                                 ('family', MinMaxScaler(), ['family'])])

# %%
# fit and transform the training data

preprocessor.fit_transform(x_train)
# Out:
#      age__age  fare__fare  embarked___embarked  sex__sex_female  \
# 789  1.133411    2.071412             0.191646              0.0
# 723  1.418317   -0.608225             1.000000              0.0
# 141 -0.576021   -0.829161             1.000000              1.0
# 388 -0.077437   -0.830037             0.000000              0.0
# 56  -0.647248   -0.713433             1.000000              1.0
# ..        ...         ...                  ...              ...
# 72  -0.647248    1.937798             1.000000              0.0
# 112 -0.576021   -0.816536             1.000000              0.0
# 287 -0.576021   -0.823026             1.000000              0.0
# 483  2.344259   -0.751834             1.000000              1.0
# 108  0.563600   -0.823026             1.000000              0.0
#
#      sex__sex_male  family__family  remainder__pclass
# 789            1.0             0.0                  1
# 723            1.0             0.0                  2
# 141            0.0             0.0                  3
# 388            1.0             0.0                  3
# 56             0.0             0.0                  2
# ..             ...             ...                ...
# 72             1.0             0.0                  2
# 112            1.0             0.0                  3
# 287            1.0             0.0                  3
# 483            0.0             0.0                  3
# 108            1.0             0.0                  3
#
# [623 rows x 7 columns]

# %%
display(preprocessor.get_params())
# Out:
# {'force_int_remainder_cols': True,
#  'n_jobs': -1,
#  'remainder': 'passthrough',
#  'sparse_threshold': 0.3,
#  'transformer_weights': None,
#  'transformers': [('age',
#    Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
#                    ('outliers', Winsorizer(fold=3)), ('scale', StandardScaler())]),
#    ['age']),
#   ('fare',
#    Pipeline(steps=[('outliers', Winsorizer(capping_method='iqr', fold=1.5)),
#                    ('scale', StandardScaler())]),
#    ['fare']),
#   ('embarked_',
#    Pipeline(steps=[('impute', SimpleImputer(strategy='most_frequent')),
#                    ('count_encode', CountFrequencyEncoder()),
#                    ('scale', MinMaxScaler())]),
#    ['embarked']),
#   ('sex',
#    OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#    ['sex']),
#   ('family', MinMaxScaler(), ['family'])],
#  'verbose': False,
#  'verbose_feature_names_out': True,
#  'age': Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
#                  ('outliers', Winsorizer(fold=3)), ('scale', StandardScaler())]),
#  'fare': Pipeline(steps=[('outliers', Winsorizer(capping_method='iqr', fold=1.5)),
#                  ('scale', StandardScaler())]),
#  'embarked_': Pipeline(steps=[('impute', SimpleImputer(strategy='most_frequent')),
#                  ('count_encode', CountFrequencyEncoder()),
#                  ('scale', MinMaxScaler())]),
#  'sex': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'family': MinMaxScaler(),
#  'age__memory': None,
#  'age__steps': [('impute', SimpleImputer(strategy='median')),
#   ('outliers', Winsorizer(fold=3)),
#   ('scale', StandardScaler())],
#  'age__transform_input': None,
#  'age__verbose': False,
#  'age__impute': SimpleImputer(strategy='median'),
#  'age__outliers': Winsorizer(fold=3),
#  'age__scale': StandardScaler(),
#  'age__impute__add_indicator': False,
#  'age__impute__copy': True,
#  'age__impute__fill_value': None,
#  'age__impute__keep_empty_features': False,
#  'age__impute__missing_values': nan,
#  'age__impute__strategy': 'median',
#  'age__outliers__add_indicators': False,
#  'age__outliers__capping_method': 'gaussian',
#  'age__outliers__fold': 3,
#  'age__outliers__missing_values': 'raise',
#  'age__outliers__tail': 'right',
#  'age__outliers__variables': None,
#  'age__scale__copy': True,
#  'age__scale__with_mean': True,
#  'age__scale__with_std': True,
#  'fare__memory': None,
#  'fare__steps': [('outliers', Winsorizer(capping_method='iqr', fold=1.5)),
#   ('scale', StandardScaler())],
#  'fare__transform_input': None,
#  'fare__verbose': False,
#  'fare__outliers': Winsorizer(capping_method='iqr', fold=1.5),
#  'fare__scale': StandardScaler(),
#  'fare__outliers__add_indicators': False,
#  'fare__outliers__capping_method': 'iqr',
#  'fare__outliers__fold': 1.5,
#  'fare__outliers__missing_values': 'raise',
#  'fare__outliers__tail': 'right',
#  'fare__outliers__variables': None,
#  'fare__scale__copy': True,
#  'fare__scale__with_mean': True,
#  'fare__scale__with_std': True,
#  'embarked___memory': None,
#  'embarked___steps': [('impute', SimpleImputer(strategy='most_frequent')),
#   ('count_encode', CountFrequencyEncoder()),
#   ('scale', MinMaxScaler())],
#  'embarked___transform_input': None,
#  'embarked___verbose': False,
#  'embarked___impute': SimpleImputer(strategy='most_frequent'),
#  'embarked___count_encode': CountFrequencyEncoder(),
#  'embarked___scale': MinMaxScaler(),
#  'embarked___impute__add_indicator': False,
#  'embarked___impute__copy': True,
#  'embarked___impute__fill_value': None,
#  'embarked___impute__keep_empty_features': False,
#  'embarked___impute__missing_values': nan,
#  'embarked___impute__strategy': 'most_frequent',
#  'embarked___count_encode__encoding_method': 'count',
#  'embarked___count_encode__ignore_format': False,
#  'embarked___count_encode__missing_values': 'raise',
#  'embarked___count_encode__unseen': 'ignore',
#  'embarked___count_encode__variables': None,
#  'embarked___scale__clip': False,
#  'embarked___scale__copy': True,
#  'embarked___scale__feature_range': (0, 1),
#  'sex__categories': 'auto',
#  'sex__drop': None,
#  'sex__dtype': numpy.float64,
#  'sex__feature_name_combiner': 'concat',
#  'sex__handle_unknown': 'ignore',
#  'sex__max_categories': None,
#  'sex__min_frequency': None,
#  'sex__sparse_output': False,
#  'family__clip': False,
#  'family__copy': True,
#  'family__feature_range': (0, 1)}

# %%
model_params=RandomForestClassifier().get_params()
model_params
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
model_pipe = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('clf',RandomForestClassifier(**model_params))
])

model_pipe
# Out:
# C:\Users\Santosh Kumar_TSI\anaconda3\envs\myenv\lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('age',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('outliers',
#                                                                    Winsorizer(fold=3)),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['age']),
#                                                  ('fare',
#                                                   Pipeline(steps=[('outliers',
#                                                                    Winsorizer(capping_method='iqr',
#                                                                               fold=1.5)),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['fare']),
#                                                  ('embarked_',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('count_encode',
#                                                                    CountFrequencyEncoder()),
#                                                                   ('scale',
#                                                                    MinMaxScaler())]),
#                                                   ['embarked']),
#                                                  ('sex',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['sex']),
#                                                  ('family', MinMaxScaler(),
#                                                   ['family'])])),
#                 ('clf', RandomForestClassifier())])

# %%
# fit the model on the training data

model=model_pipe.fit(x_train,y_train)
model
# Out:
# C:\Users\Santosh Kumar_TSI\anaconda3\envs\myenv\lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('age',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('outliers',
#                                                                    Winsorizer(fold=3)),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['age']),
#                                                  ('fare',
#                                                   Pipeline(steps=[('outliers',
#                                                                    Winsorizer(capping_method='iqr',
#                                                                               fold=1.5)),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['fare']),
#                                                  ('embarked_',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('count_encode',
#                                                                    CountFrequencyEncoder()),
#                                                                   ('scale',
#                                                                    MinMaxScaler())]),
#                                                   ['embarked']),
#                                                  ('sex',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['sex']),
#                                                  ('family', MinMaxScaler(),
#                                                   ['family'])])),
#                 ('clf', RandomForestClassifier())])

# %%
# evaluate the model on the test data

y_pred = model_pipe.predict(x_test)

accuracy = accuracy_score(y_test,y_pred)
precision = precision_score(y_test,y_pred)
recall = recall_score(y_test,y_pred)
f1 = f1_score(y_test,y_pred)

# %%
# metrics dict

metrics = {
    'accuracy': accuracy,
    'precision': precision,
    'recall': recall,
    'f1_score': f1
}

metrics
# Out:
# {'accuracy': 0.8012820512820513,
#  'precision': 0.7857142857142857,
#  'recall': 0.6984126984126984,
#  'f1_score': 0.7394957983193278}

# %%
# plot confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, roc_auc_score,log_loss
cm = ConfusionMatrixDisplay.from_predictions(y_test,y_pred)
cm.ax_.grid(False)

# %%
# !pip install mlflow --q

# %%
import mlflow

# %%
x_test.join(y_test)
# Out:
#      pclass     sex   age     fare embarked  family  survived
# 677       3  female  18.0   9.8417        S       0         1
# 668       3    male  43.0   8.0500        S       0         0
# 615       2  female  24.0  65.0000        S       3         1
# 729       3  female  25.0   7.9250        S       1         0
# 546       2  female  19.0  26.0000        S       1         1
# ..      ...     ...   ...      ...      ...     ...       ...
# 382       3    male  32.0   7.9250        S       0         0
# 82        3  female   NaN   7.7875        Q       0         1
# 156       3  female  16.0   7.7333        Q       0         1
# 362       3  female  45.0  14.4542        C       1         0
# 177       1  female  50.0  28.7125        C       0         0
#
# [156 rows x 7 columns]

# %%
import mlflow
import mlflow.sklearn
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, 
    roc_auc_score, log_loss, ConfusionMatrixDisplay
)

# Set the URI for the MLflow server
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# Set the experiment
mlflow.set_experiment("exp1")

with mlflow.start_run() as run:
    # Log the data signature
    data_signature = mlflow.models.infer_signature(
        model_input=x_train, model_output=model_pipe.predict(x_train)
    )

    # Log preprocessor parameters
    mlflow.log_params(model_pipe.get_params())

    # Generate predictions
    y_pred_train = model_pipe.predict(x_train)
    y_pred_test = model_pipe.predict(x_test)

    y_proba_train = model_pipe.predict_proba(x_train)[:, 1]  # Probability estimates for train
    y_proba_test = model_pipe.predict_proba(x_test)[:, 1]  # Probability estimates for test

    # Calculate metrics
    metrics = {
        "train_accuracy": accuracy_score(y_train, y_pred_train),
        "test_accuracy": accuracy_score(y_test, y_pred_test),
        "train_precision": precision_score(y_train, y_pred_train),
        "test_precision": precision_score(y_test, y_pred_test),
        "train_recall": recall_score(y_train, y_pred_train),
        "test_recall": recall_score(y_test, y_pred_test),
        "train_f1_score": f1_score(y_train, y_pred_train),
        "test_f1_score": f1_score(y_test, y_pred_test),
        "train_roc_auc": roc_auc_score(y_train, y_proba_train),
        "test_roc_auc": roc_auc_score(y_test, y_proba_test),
        "train_log_loss": log_loss(y_train, y_proba_train),
        "test_log_loss": log_loss(y_test, y_proba_test)
    }

    # Log the metrics
    mlflow.log_metrics({k: float(v) for k, v in metrics.items()})

    # Log the trained model
    mlflow.sklearn.log_model(sk_model=model_pipe, artifact_path="model", signature=data_signature)

    # Log the notebook file if it exists
    notebook_path = "C:/Users/Santosh Kumar_TSI/mlflow-git/mlflow1.ipynb"
    try:
        mlflow.log_artifact(notebook_path)
    except FileNotFoundError:
        print(f"Notebook file '{notebook_path}' not found. Skipping artifact logging.")

    # Save and log datasets
    x_train.to_csv("x_train.csv", index=False)
    x_test.to_csv("x_test.csv", index=False)
    y_train.to_csv("y_train.csv", index=False)
    y_test.to_csv("y_test.csv", index=False)

    mlflow.log_artifact("x_train.csv", artifact_path="data/training")
    mlflow.log_artifact("y_train.csv", artifact_path="data/training")
    mlflow.log_artifact("x_test.csv", artifact_path="data/test")
    mlflow.log_artifact("y_test.csv", artifact_path="data/test")

    # Save and log the confusion matrix
    cm = ConfusionMatrixDisplay.from_estimator(model_pipe, x_test, y_test)
    cm.ax_.grid(False)
    
    plt.savefig("confusion_matrix.png")  # Explicitly save before logging
    mlflow.log_artifact("confusion_matrix.png", artifact_path="figures")
    plt.close()  # Close the plot to prevent overlap in future runs
# Out:
# C:\Users\Santosh Kumar_TSI\anaconda3\envs\myenv\lib\site-packages\mlflow\types\utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run zealous-pig-530 at: http://127.0.0.1:5000/#/experiments/821494323167535920/runs/62138d780ad04357ae37a69d685b56fd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/821494323167535920

# %%
import mlflow
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Define the params for RF model
max_depth = 10
n_estimators = 5
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("exp2")

with mlflow.start_run():
    model_pipe = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('clf', RandomForestClassifier(max_depth=max_depth, n_estimators=n_estimators, random_state=42))
    ])
    
    model_pipe.fit(x_train, y_train)
    y_pred = model_pipe.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)

    mlflow.log_metric('accuracy', accuracy)
    mlflow.log_param('max_depth', max_depth)
    mlflow.log_param('n_estimators', n_estimators)

    # Creating a confusion matrix plot
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6,6))
    class_labels = ["Not Survived", "Survived"]
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.title('Confusion Matrix')

    # Save plot
    plt.savefig("Confusion-matrix.png")

    # Log artifacts using mlflow
    mlflow.log_artifact("Confusion-matrix.png")
    

    # Tags
    mlflow.set_tags({"Author": 'santosh', "Project": "Titanic survival"})

    # Log the model
    mlflow.sklearn.log_model(model_pipe, "Random-Forest-Model")

    print(accuracy)

# %%
# Retrieve the default parameters of the RandomForestClassifier
model_params = RandomForestClassifier().get_params()

# Modify the values for n_estimators and max_depth
model_params['n_estimators'] = 8
model_params['max_depth'] = 10

mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("exp3")
mlflow.sklearn.autolog()

with mlflow.start_run():
    model_pipe = Pipeline(steps=[
        ('preprocessor', preprocessor),  
        ('clf', RandomForestClassifier(**model_params))
    ])

    # metrics
    model_pipe.fit(x_train, y_train)  
    y_pred = model_pipe.predict(x_test)  
    y_proba = model_pipe.predict_proba(x_test)[:, 1]  # Probability estimates for ROC AUC & log loss
    accuracy = accuracy_score(y_test, y_pred)  
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)  

    # log roc_auc & log_loss manually
    test_metrics = {
        "roc_auc_x_test": roc_auc_score(y_test, y_proba),
        "log_loss_x_test": log_loss(y_test, y_proba)  
    }

    mlflow.log_metrics(test_metrics)

    #log the file
    mlflow.log_artifact('C:/Users/Santosh Kumar_TSI/mlflow-git/mlflow1.ipynb')

    # Log the confusion matrix
    cm = ConfusionMatrixDisplay.from_estimator(model_pipe, x_test, y_test,)
    cm.ax_.grid(False)
    cm.figure_.savefig("confusion_matrix.png")
    mlflow.log_artifact("confusion_matrix.png", artifact_path="figures")

    # Tags
    mlflow.set_tags({"Author": 'santosh', "Project": "Titanic survival"})

# %%
import mlflow
import mlflow.sklearn

# Set MLflow tracking URI and experiment name
mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("exp4")

with mlflow.start_run() as run:
    # Log the model with signature
    data_signature = mlflow.models.infer_signature(x_train, model_pipe.predict(x_train))
    mlflow.sklearn.log_model(model_pipe, "model", signature=data_signature)

    # Get model URI
    model_uri = mlflow.get_artifact_uri("model")

    # Evaluate the model (automatically logs metrics and artifacts)
    result = mlflow.evaluate(
        model=model_uri,
        data=x_test.join(y_test),  # Ensure indices align
        targets=y_test.name,       # Use correct target column name
        model_type="classifier",
        evaluators=["default"]     # Logs accuracy, precision, recall, ROC AUC, etc.
    )

    # MLflow will now automatically log:
    # ✅ Accuracy, Precision, Recall, F1-score, ROC AUC, Log Loss, etc.
    # ✅ Confusion matrix, ROC Curve, Precision-Recall Curve
